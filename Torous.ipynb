# %%
##Import Modules
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
## Torous Parameters
R=3

r=1

##Create  nodes
x=np.linspace(0,2*np.pi,100)
y=np.linspace(0,2*np.pi,50)
x,y=np.meshgrid(x, y)

## Parametric Equation of torous
U=(R+ r * np.cos(y)) * np.cos(x)
V=(R+ r * np.cos(y)) * np.sin(x)
T=r + np.sin(y)

# %%
##Plotting
fig=plt.figure(figsize=(8,6))
ax=fig.add_subplot(111,projection="3d")
ax.plot_surface(U,V,T,rstride=1,cstride=1,color="green",edgecolor="k",alpha=0.6)

# %%
##Torous Surface

##Horizontals
for a in np.linspace(0,2*np.pi,12):
    xline=(R+r*np.cos(a))*np.cos(x[0])
    yline=(R+r*np.cos(a))*np.sin(x[0])
    zline=r*np.sin(a) * np.ones_like(x[0])
    ax.plot(xline,yline,zline,color="darkblue",linewidth=1)

##Verticals
for b in np.linspace(0,2*np.pi,12):
    xline=(R+r*np.cos(y[:,0]))*np.cos(b)
    yline=(R+r*np.cos(y[:,0]))*np.sin(b)
    zline=r*np.sin(y[:,0]) 
    ax.plot(xline,yline,zline,color="darkred",linewidth=1)

ax.set_box_aspect([1,1,1])
ax.axis('off')
plt.title("Torous")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# Define the parametric equations for the torus
def torus(R, r, u, v):
    x = (R + r * np.cos(v)) * np.cos(u)
    y = (R + r * np.cos(v)) * np.sin(u)
    z = r * np.sin(v)
    return x, y, z
# Create a grid of the u and v values
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, 2 * np.pi, 100)
u, v = np.meshgrid(u, v)
# Calculate the coordinates of the torus
R = 3 
r = 1  
x, y, z = torus(R, r, u, v)
# Plot the torus
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z, color='c', edgecolor='k', alpha=0.6)
# Labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Parametric Surface: Torus')
# Show the plot
plt.show()
